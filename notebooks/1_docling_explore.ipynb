# %%
from pathlib import Path

from docling.document_converter import DocumentConverter

# %%
pdf_path = Path("../data/input_docs/eu_ai_act_2024_1689_DE.pdf")

converter = DocumentConverter()
result = converter.convert(pdf_path)

doc = result.document
# Out:
# [INFO] 2026-08-12 15:23:47,996 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-12 15:23:48,086 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-12 15:23:48,165 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.pth
# [INFO] 2026-08-12 15:23:48,170 [RapidOCR] main.py:50: Using C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.pth
# [INFO] 2026-08-12 15:23:48,847 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-12 15:23:48,847 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-12 15:23:48,862 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...
