# %%
import os
os.environ["TORCHDYNAMO_DISABLE"] = "1" # windows issue incompatibility

from docling.document_converter import DocumentConverter
from pathlib import Path
from backend.config import settings
import json

# %% [markdown]
# ### Exploring functions

# %%
# pdf_path = list(settings.DOCUMENTS_IN_DIR.glob("*.pdf"))[0]

# converter = DocumentConverter()
# result = converter.convert(pdf_path)

# doc = result.document

# %%
# print(result.status)
# print(len(doc.texts))
# print(doc.export_to_markdown()[:2000])

# %%
from backend.ingestion import read_documents_and_save
read_documents_and_save()
# Out:
# [INFO] 2026-08-31 20:10:21,269 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-31 20:10:21,336 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-31 20:10:21,366 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.pth
# [INFO] 2026-08-31 20:10:21,369 [RapidOCR] main.py:50: Using C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.pth
# [INFO] 2026-08-31 20:10:22,172 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-31 20:10:22,176 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-31 20:10:22,186 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\admin\Programming\RAG-Systems\classic-RAG\Classic-RAG\.venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...
